# %%
from common import *
from pandas.api.types import CategoricalDtype
import warnings 
warnings.filterwarnings('ignore')
debug = O()
# %matplotlib inline
canvas(12,12)

# %%
M = pd.read_pickle(top_dir+'data/given/M.pkl')
N = pd.read_pickle(top_dir+'data/given/N.pkl')
#test = pd.read_pickle(top_dir+'data/given/test.pkl')

# %%
assetCodeSeries = pd.Series(M.assetCode.unique())
numAssetCode = len(assetCodeSeries)
#assetCodeCategorical = CategoricalDtype(assetCodeSeries, ordered=False)
#assetCodeSeries = assetCodeSeries.astype(assetCodeCategorical)
assetCodeIdMap = {x: i for i,x in enumerate(assetCodeSeries)}
#assetCodeIndex = pd.Index(assetCodeSeries)
#assetCodeIndexedDf = assetCodeIndex.to_frame().drop(0,axis=1)

assetNameSeries = pd.Series(M.assetName.unique())
numAssetName = len(assetNameSeries)
#assetNameCategorical = CategoricalDtype(assetNameSeries, ordered=False)
#assetNameSeries = assetNameSeries.astype(assetNameCategorical)
assetNameIdMap = {x: i for i,x in enumerate(assetNameSeries)}
#assetNameIndex = pd.Index(assetNameSeries)
#assetNameIndexedDf = assetNameIndex.to_frame().drop(0,axis=1)

# %%
returns_columns = {
    'returnsClosePrevRaw1':'cc', 'returnsOpenPrevRaw1':'oo',
    'returnsClosePrevMktres1':'cc0', 'returnsOpenPrevMktres1':'oo0',
    'returnsClosePrevRaw10':'cc_10','returnsOpenPrevRaw10':'oo_10',
    'returnsClosePrevMktres10':'cc0_10','returnsOpenPrevMktres10':'oo0_10'
}
excluded_columns = [
    'time','assetCode','assetName','universe','returnsOpenNextMktres10','quarter'
]
column_filter = lambda c: c not in returns_columns and c not in excluded_columns

# %%
def add_basic_features(*,M):
    M['assetCodeId'] = M.assetCode.map(assetCodeIdMap)
    M['assetNameId'] = M.assetName.map(assetNameIdMap)
    for orig_col, new_col in returns_columns.items():
        M[new_col] = np.log(M[orig_col]+1)
    # time features
    M['dayOfYear'] = M.time.dt.dayofyear
    M['dayOfWeek'] = M.time.dt.dayofweek
    
def add_shortterm_price_features(*,U,extend=False):
    U['(oo-oo0)_'] = U.oo_ - U.oo0_
    
    for ww in ['oo','oo0','(oo-oo0)']:
        ww_ = ww+'_'
        if extend:
            window = np.flip(U[ww_],axis=0)[:20]
        else:
            windows = np.stack([np.shift(U[ww_],i,axis=0) for i in range(20)], axis=-1) # NaNs are 0
        for c in combos.ckco(20,5):
            name = '{}{{{}}}'.format(ww_, combos.name.consec(c))
            if extend:
                U[name] = np.concatenate([U[name], (c@window)[np.newaxis,:]], axis=0)
            else:
                U[name] = windows@c
    #################################################################
    U['(oo-oo0)*'] = U.oo - U.oo0
    U['(cc-cc0)*'] = U.cc - U.cc0
    
    for ww in ['(oo-oo0)','(cc-cc0)']:
        if extend:
            window = np.flip(U[ww+'*'],axis=0)[:3]
        else:
            windows = np.stack([np.shift(U[ww+'*'],i,axis=0) for i in range(3)], axis=-1) # NaNs are 0
        for c in combos.union(combos.omo(3),combos.mintco(3,1,1)):
            name = '{}{{{}}}'.format(ww, combos.name.index(c))
            if extend:
                U[name] = np.concatenate([U[name], (c@window)[np.newaxis,:]], axis=0)
            else:
                U[name] = windows@c
    #################################################################
    U['af'] = np.log(U.open/np.shift(U.close,1,axis=0))
    U['it'] = np.log(U.close/U.open)
    U['af{1}'] = np.shift(U.af,1,axis=0)
    U['it{1}'] = np.shift(U.it,1,axis=0)
    
    if extend:
        near_datum = np.stack([U.it[-1],U.af[-1],U.it[-2]], axis=0) # can be NaNs
    else:
        near_data = np.stack([U.it,U.af,U['it{1}']], axis=-1) # can be NaNs
    for c in combos.omo(3):
        name = '(it,af,it{{1}}){{{}}}'.format(combos.name.index(c))
        if extend:
            U[name] = np.concatenate([U[name], (c@near_datum)[np.newaxis,:]], axis=0)
        else:
            U[name] = near_data@c
            
    
def add_longterm_price_features(*,U,horizons=[21,62,125,250]):
    U['oo0_20'] = U.oo0_10_ + np.shift(U.oo0_10_,10,axis=0)
    U['oo0_60'] = (U.oo0_10_ + np.shift(U.oo0_10_,10,axis=0) + np.shift(U.oo0_10_,20,axis=0)
                   + np.shift(U.oo0_10_,30,axis=0) + np.shift(U.oo0_10_,40,axis=0) + np.shift(U.oo0_10_,50,axis=0)
    for ww in ['oo','oo0']:
        for h in horizons:
            strh = str(h)
            since = U[ww+'Since'+strh] = U[ww+'_'][-h:].cumsum(axis=0)
                   
            maxSince = U[ww+'MaxSince'+strh] = np.maximum.accumulate(since)
            drawdownSince = U[ww+'DrawdownSince'+strh] = maxSince - since
            maxDrawdown5Since = U[ww+'MaxDrawdown5Since'+strh] = drawdownSince[-5:].max(axis=0)[np.newaxis,:]
            maxDrawdown10Since = U[ww+'MaxDrawdown10Since'+strh] = drawdownSince[-10:].max(axis=0)[np.newaxis,:]
            maxDrawdown20Since = U[ww+'MaxDrawdown20Since'+strh] = drawdownSince[-20:].max(axis=0)[np.newaxis,:]
            #maxDrawdown10_5Since = U[ww+'MaxDrawdown(10-5)Since'+strh] = drawdownSince[-10:-5].max(axis=0)[np.newaxis,:]
            #maxDrawdown20_10Since = U[ww+'MaxDrawdown(20-10)Since'+strh] = drawdownSince[-20:-10].max(axis=0)[np.newaxis,:]
            prev5MaxSince = U[ww+'Prev5MaxSince'+strh] = np.shift(maxSince, 5, axis=0)
            prev10MaxSince = U[ww+'Prev10MaxSince'+strh] = np.shift(maxSince, 10, axis=0)
            prev20MaxSince = U[ww+'Prev20MaxSince'+strh] = np.shift(maxSince, 20, axis=0)
            
            minSince = U[ww+'MinSince'+strh] = np.minimum.accumulate(since)
            #drawupSince = U[ww+'DrawupSince'+strh] = since - minSince
            #maxDrawup5Since = U[ww+'MaxDrawup5Since'+strh] = drawupSince[-5:].max(axis=0)[np.newaxis,:]
            #maxDrawup10Since = U[ww+'MaxDrawup10Since'+strh] = drawupSince[-10:].max(axis=0)[np.newaxis,:]
            #maxDrawup20Since = U[ww+'MaxDrawup20Since'+strh] = drawupSince[-20:].max(axis=0)[np.newaxis,:]
            #maxDrawup10_5Since = U[ww+'MaxDrawup(10-5)Since'+strh] = drawupSince[-10:-5].max(axis=0)[np.newaxis,:]
            #maxDrawup20_10Since = U[ww+'MaxDrawup(20-10)Since'+strh] = drawupSince[-20:-10].max(axis=0)[np.newaxis,:]
            prev5MinSince = U[ww+'Prev5MinSince'+strh] = np.shift(minSince, 5, axis=0)
            prev10MinSince = U[ww+'Prev10MinSince'+strh] = np.shift(minSince, 10, axis=0)
            prev20MinSince = U[ww+'Prev20MinSince'+strh] = np.shift(minSince, 20, axis=0)

# %%
def make_single_A_U(*,M):
    A = M[~M.assetCodeId.isna()] # ditch the unseen assetCodes
    A = pd.DataFrame(index=pd.Series(range(numAssetCode),name='assetCodeId')).join(
        A.set_index('assetCodeId')) # join onto standard assetCode row-index
    V = O(**{c:A[c] for c in A})
    U = O(**{c:df.values[np.newaxis,:] for c,df in dict.items(V) if column_filter(c)},
          **{c+'_':np.nan_to_num(df.values[np.newaxis,:]) for c,df in dict.items(V) if column_filter(c)})
    return A, U
def make_U(*,M):
    Us = [make_single_A_U(M=m)[1] for _,m in M.groupby('time')]
    U = O(**{c:np.concatenate([u[c] for u in Us],axis=0) for c in Us[0]})
    return U

# %%
Minit = M[M.time<=M.time.unique()[250]]
add_basic_features(M=Minit)
Uinit = make_U(M=Minit)
add_shortterm_price_features(U=Uinit)
add_longterm_price_features(U=Uinit)

# %%
def iter_features_templates(MNP_iter, *, U_, U__):
    U_tuple, U__tuple = U_, U__
    Mcolumns = list(filter(column_filter, (c for c in Minit.columns if c[-1] not in '*_')))
    Ucolumns = list(filter(column_filter, (c for c in Uinit if c not in Mcolumns and c[-1] not in '*_')))
    U_, U_lim = U_tuple
    U__, U__lim = U__tuple
    for M, N, P in MNP_iter:
        orig_index = M.index
        add_basic_features(M=M)
        M0 = pd.DataFrame(index=M.assetCodeId)
        A, U = make_single_A_U(M=M)
        # join new row vectors in U to the old tables in U_ and U__
        for oldU, lim in [(U_, U_lim), (U__, U__lim)]:
            for key in U:
                key = str(key)
                if len(oldU[key])>lim:
                    oldU[key] = oldU[key][-lim:]
                oldU[key] = np.concatenate([oldU[key],U[key]], axis=0)
        # add features to U_ and U__
        gc.collect()
        add_shortterm_price_features(U=U_, extend=True)
        gc.collect()
        add_longterm_price_features(U=U__)
        gc.collect()
        # take out the bottom row of the feature tables to feed out as our feature construction iterator
        _dict = {c:a[-1] for c,a in dict.items(U_)}
        _dict.update({c:a[-1] for c,a in dict.items(U__)})
        features = pd.DataFrame([_dict[c] for c in Ucolumns], index=Ucolumns, columns=A.index).T
        debug.A = A
        features = pd.concat([A.reset_index()[Mcolumns],features], axis=1)
        features = M0.join(features)
        features.index = orig_index
        yield features, P

# %%
train_start_time = pd.Timestamp('2009-01-01',tz='UTC')
U_lim = 21
U__lim = 250

def iter_MNP_train(*,M,N):
    M_, N_ = M, N
    for time, M in M_.groupby('time'):
        if time<train_start_time:
            continue
        M['quarter'] = M.time.dt.year+(M.time.dt.quarter-1)/4
        P = M[excluded_columns]
        M = M.drop(columns=['returnsOpenNextMktres10','quarter'])
        yield M, None, P
        
Mstart = M[M.time<train_start_time]
add_basic_features(M=Mstart)
U_ = make_U(M=Mstart)
add_shortterm_price_features(U=U_)
U__ = O(**{k:x.copy() for k,x in dict.items(U_)})

# %%
def make_train_extrafault():
    itfeat = iter_features_templates(iter_MNP_train(M=M,N=N), U_=(U_,U_lim), U__=(U__,U__lim))
    train = [[print_progress(i,10),(F,P)][-1] for i,(F,P) in enumerate(itfeat)]
    F = pd.concat([FP[0] for FP in train], axis=0)
    P = pd.concat([FP[1] for FP in train], axis=0)
    F.index = P.index
    return F,P
#F,P = make_train_extrafault()
# Out:
# 0.........100.........200.........300.........400.........500.........600.........700.........800.........900.........1000.........1100.........1200.........1300.........1400.........1500.........1600.........1700.........1800.........1900.........2000.

# %%
#F.assetNameId = F.assetNameId.astype(int)

#pd.to_pickle((F,P), top_dir+'data/saves/train_extrafault.pkl')
F,P = pd.read_pickle(top_dir+'data/saves/train_newfault.pkl')

# %%
#F.assetNameId = F.assetNameId.astype(int)

#pd.to_pickle((F,P), top_dir+'data/saves/train_extrafault.pkl')
F0,P0 = pd.read_pickle(top_dir+'data/saves/train_newfault.pkl')

# %%
for line in F0.columns:
    print(line)
# Out:
# volume
# close
# open
# assetCodeId
# assetNameId
# cc
# oo
# cc0
# oo0
# cc_10
# oo_10
# cc0_10
# oo0_10
# dayOfYear
# dayOfWeek
# af
# it
# oo{(0..4)^1}
# oo{(0..9)^1}
# oo{(0..14)^1}
# oo{(0..19)^1}
# oo{(5..9)^1}
# oo{(5..14)^1}
# oo{(5..19)^1}
# oo{(10..14)^1}
# oo{(10..19)^1}
# oo{(15..19)^1}
# oo0{(0..4)^1}
# oo0{(0..9)^1}
# oo0{(0..14)^1}
# oo0{(0..19)^1}
# oo0{(5..9)^1}
# oo0{(5..14)^1}
# oo0{(5..19)^1}
# oo0{(10..14)^1}
# oo0{(10..19)^1}
# oo0{(15..19)^1}
# (it,af,it[1],oo0,cc0){0/1}
# (it,af,it[1],oo0,cc0){0/2}
# (it,af,it[1],oo0,cc0){0/3}
# (it,af,it[1],oo0,cc0){0/4}
# (it,af,it[1],oo0,cc0){1/2}
# (it,af,it[1],oo0,cc0){1/3}
# (it,af,it[1],oo0,cc0){1/4}
# (it,af,it[1],oo0,cc0){2/3}
# (it,af,it[1],oo0,cc0){2/4}
# (it,af,it[1],oo0,cc0){3/4}
# oo0_20
# ooSince21
# ooMaxSince21
# ooDrawdownSince21
# ooMaxDrawdown5Since21
# ooMaxDrawdown10Since21
# ooPrev5MaxSince21
# ooMinSince21
# ooPrev5MinSince21
# ooSince62
# ooMaxSince62
# ooDrawdownSince62
# ooMaxDrawdown5Since62
# ooMaxDrawdown10Since62
# ooPrev5MaxSince62
# ooMinSince62
# ooPrev5MinSince62
# ooSince125
# ooMaxSince125
# ooDrawdownSince125
# ooMaxDrawdown5Since125
# ooMaxDrawdown10Since125
# ooPrev5MaxSince125
# ooMinSince125
# ooPrev5MinSince125
# ooSince250
# ooMaxSince250
# ooDrawdownSince250
# ooMaxDrawdown5Since250
# ooMaxDrawdown10Since250
# ooPrev5MaxSince250
# ooMinSince250
# ooPrev5MinSince250
# oo0Since21
# oo0MaxSince21
# oo0DrawdownSince21
# oo0MaxDrawdown5Since21
# oo0MaxDrawdown10Since21
# oo0Prev5MaxSince21
# oo0MinSince21
# oo0Prev5MinSince21
# oo0Since62
# oo0MaxSince62
# oo0DrawdownSince62
# oo0MaxDrawdown5Since62
# oo0MaxDrawdown10Since62
# oo0Prev5MaxSince62
# oo0MinSince62
# oo0Prev5MinSince62
# oo0Since125
# oo0MaxSince125
# oo0DrawdownSince125
# oo0MaxDrawdown5Since125
# oo0MaxDrawdown10Since125
# oo0Prev5MaxSince125
# oo0MinSince125
# oo0Prev5MinSince125
# oo0Since250
# oo0MaxSince250
# oo0DrawdownSince250
# oo0MaxDrawdown5Since250
# oo0MaxDrawdown10Since250
# oo0Prev5MaxSince250
# oo0MinSince250
# oo0Prev5MinSince250

# %%
fNew = set(F0.columns)
fExtra = set(F1.columns)
fExtra-fNew
# Out:
# {'(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/1}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/2}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/3}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/4}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/5}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/6}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{0/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/2}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/3}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/4}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/5}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/6}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{1/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/3}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/4}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/5}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/6}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{2/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/4}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/5}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/6}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{3/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/5}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/6}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{4/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/6}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{5/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/7}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{6/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{7/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{7/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{7/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{7/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{7/8}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{7/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{8/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{8/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{8/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{8/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{8/9}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{9/10}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{9/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{9/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{9/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{a/11}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{a/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{a/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{b/12}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{b/13}',
#  '(it,af,it{1},oo,cc,oo0,cc0)*{0,1}{c/13}',
#  'oo0DrawupSince125',
#  'oo0DrawupSince21',
#  'oo0DrawupSince250',
#  'oo0DrawupSince62',
#  'oo0MaxDrawdown(10-5)Since125',
#  'oo0MaxDrawdown(10-5)Since21',
#  'oo0MaxDrawdown(10-5)Since250',
#  'oo0MaxDrawdown(10-5)Since62',
#  'oo0MaxDrawdown(20-10)Since125',
#  'oo0MaxDrawdown(20-10)Since21',
#  'oo0MaxDrawdown(20-10)Since250',
#  'oo0MaxDrawdown(20-10)Since62',
#  'oo0MaxDrawdown20Since125',
#  'oo0MaxDrawdown20Since21',
#  'oo0MaxDrawdown20Since250',
#  'oo0MaxDrawdown20Since62',
#  'oo0MaxDrawup(10-5)Since125',
#  'oo0MaxDrawup(10-5)Since21',
#  'oo0MaxDrawup(10-5)Since250',
#  'oo0MaxDrawup(10-5)Since62',
#  'oo0MaxDrawup(20-10)Since125',
#  'oo0MaxDrawup(20-10)Since21',
#  'oo0MaxDrawup(20-10)Since250',
#  'oo0MaxDrawup(20-10)Since62',
#  'oo0MaxDrawup10Since125',
#  'oo0MaxDrawup10Since21',
#  'oo0MaxDrawup10Since250',
#  'oo0MaxDrawup10Since62',
#  'oo0MaxDrawup20Since125',
#  'oo0MaxDrawup20Since21',
#  'oo0MaxDrawup20Since250',
#  'oo0MaxDrawup20Since62',
#  'oo0MaxDrawup5Since125',
#  'oo0MaxDrawup5Since21',
#  'oo0MaxDrawup5Since250',
#  'oo0MaxDrawup5Since62',
#  'oo0Prev10MaxSince125',
#  'oo0Prev10MaxSince21',
#  'oo0Prev10MaxSince250',
#  'oo0Prev10MaxSince62',
#  'oo0Prev10MinSince125',
#  'oo0Prev10MinSince21',
#  'oo0Prev10MinSince250',
#  'oo0Prev10MinSince62',
#  'oo0Prev20MaxSince125',
#  'oo0Prev20MaxSince21',
#  'oo0Prev20MaxSince250',
#  'oo0Prev20MaxSince62',
#  'oo0Prev20MinSince125',
#  'oo0Prev20MinSince21',
#  'oo0Prev20MinSince250',
#  'oo0Prev20MinSince62',
#  'oo0{(0..0)^1}',
#  'oo0{(0..1)^1}',
#  'oo0{(0..11)^1}',
#  'oo0{(0..17)^1}',
#  'oo0{(0..2)^1}',
#  'oo0{(0..20)^1}',
#  'oo0{(0..3)^1}',
#  'oo0{(0..5)^1}',
#  'oo0{(0..8)^1}',
#  'oo0{(1..1)^1}',
#  'oo0{(1..2)^1}',
#  'oo0{(1..3)^1}',
#  'oo0{(1..4)^1}',
#  'oo0{(12..14)^1}',
#  'oo0{(12..17)^1}',
#  'oo0{(12..20)^1}',
#  'oo0{(15..17)^1}',
#  'oo0{(15..20)^1}',
#  'oo0{(18..20)^1}',
#  'oo0{(2..2)^1}',
#  'oo0{(2..3)^1}',
#  'oo0{(2..4)^1}',
#  'oo0{(3..11)^1}',
#  'oo0{(3..14)^1}',
#  'oo0{(3..17)^1}',
#  'oo0{(3..20)^1}',
#  'oo0{(3..3)^1}',
#  'oo0{(3..4)^1}',
#  'oo0{(3..5)^1}',
#  'oo0{(3..8)^1}',
#  'oo0{(4..4)^1}',
#  'oo0{(6..11)^1}',
#  'oo0{(6..14)^1}',
#  'oo0{(6..17)^1}',
#  'oo0{(6..20)^1}',
#  'oo0{(6..8)^1}',
#  'oo0{(9..11)^1}',
#  'oo0{(9..14)^1}',
#  'oo0{(9..17)^1}',
#  'oo0{(9..20)^1}',
#  'ooDrawupSince125',
#  'ooDrawupSince21',
#  'ooDrawupSince250',
#  'ooDrawupSince62',
#  'ooMaxDrawdown(10-5)Since125',
#  'ooMaxDrawdown(10-5)Since21',
#  'ooMaxDrawdown(10-5)Since250',
#  'ooMaxDrawdown(10-5)Since62',
#  'ooMaxDrawdown(20-10)Since125',
#  'ooMaxDrawdown(20-10)Since21',
#  'ooMaxDrawdown(20-10)Since250',
#  'ooMaxDrawdown(20-10)Since62',
#  'ooMaxDrawdown20Since125',
#  'ooMaxDrawdown20Since21',
#  'ooMaxDrawdown20Since250',
#  'ooMaxDrawdown20Since62',
#  'ooMaxDrawup(10-5)Since125',
#  'ooMaxDrawup(10-5)Since21',
#  'ooMaxDrawup(10-5)Since250',
#  'ooMaxDrawup(10-5)Since62',
#  'ooMaxDrawup(20-10)Since125',
#  'ooMaxDrawup(20-10)Since21',
#  'ooMaxDrawup(20-10)Since250',
#  'ooMaxDrawup(20-10)Since62',
#  'ooMaxDrawup10Since125',
#  'ooMaxDrawup10Since21',
#  'ooMaxDrawup10Since250',
#  'ooMaxDrawup10Since62',
#  'ooMaxDrawup20Since125',
#  'ooMaxDrawup20Since21',
#  'ooMaxDrawup20Since250',
#  'ooMaxDrawup20Since62',
#  'ooMaxDrawup5Since125',
#  'ooMaxDrawup5Since21',
#  'ooMaxDrawup5Since250',
#  'ooMaxDrawup5Since62',
#  'ooPrev10MaxSince125',
#  'ooPrev10MaxSince21',
#  'ooPrev10MaxSince250',
#  'ooPrev10MaxSince62',
#  'ooPrev10MinSince125',
#  'ooPrev10MinSince21',
#  'ooPrev10MinSince250',
#  'ooPrev10MinSince62',
#  'ooPrev20MaxSince125',
#  'ooPrev20MaxSince21',
#  'ooPrev20MaxSince250',
#  'ooPrev20MaxSince62',
#  'ooPrev20MinSince125',
#  'ooPrev20MinSince21',
#  'ooPrev20MinSince250',
#  'ooPrev20MinSince62',
#  'oo{(0..0)^1}',
#  'oo{(0..1)^1}',
#  'oo{(0..11)^1}',
#  'oo{(0..17)^1}',
#  'oo{(0..2)^1}',
#  'oo{(0..20)^1}',
#  'oo{(0..3)^1}',
#  'oo{(0..5)^1}',
#  'oo{(0..8)^1}',
#  'oo{(1..1)^1}',
#  'oo{(1..2)^1}',
#  'oo{(1..3)^1}',
#  'oo{(1..4)^1}',
#  'oo{(12..14)^1}',
#  'oo{(12..17)^1}',
#  'oo{(12..20)^1}',
#  'oo{(15..17)^1}',
#  'oo{(15..20)^1}',
#  'oo{(18..20)^1}',
#  'oo{(2..2)^1}',
#  'oo{(2..3)^1}',
#  'oo{(2..4)^1}',
#  'oo{(3..11)^1}',
#  'oo{(3..14)^1}',
#  'oo{(3..17)^1}',
#  'oo{(3..20)^1}',
#  'oo{(3..3)^1}',
#  'oo{(3..4)^1}',
#  'oo{(3..5)^1}',
#  'oo{(3..8)^1}',
#  'oo{(4..4)^1}',
#  'oo{(6..11)^1}',
#  'oo{(6..14)^1}',
#  'oo{(6..17)^1}',
#  'oo{(6..20)^1}',
#  'oo{(6..8)^1}',
#  'oo{(9..11)^1}',
#  'oo{(9..14)^1}',
#  'oo{(9..17)^1}',
#  'oo{(9..20)^1}'}

# %% [markdown]
# ### LightGBM

# %%
F, P = F1, P1

# %%
from sklearn.model_selection import GroupShuffleSplit

ho = P.quarter>=2015.5
ho.name = None
tr, cv = next(GroupShuffleSplit(n_splits=1, test_size=.5, random_state=44).split(F[~ho], P[~ho], groups=P[~ho].quarter))
_dummy = pd.Series(range(len(P)),index=P.index)
tr, cv = _dummy.isin(tr), _dummy.isin(cv)

# %%
P['target'] = P.returnsOpenNextMktres10>0
P['upDown'] = (P.target*2-1)
P['upDown1'] = P.upDown*P.universe.astype(int)
P['absVal'] = np.abs(P.returnsOpenNextMktres10)
P['absVal1'] = P.absVal*P.universe
P['weight'] = P.absVal#.qtl()
P['weight1'] = P.weight*P.universe

# %%
L = O()
featuresTime = 'dayOfYear dayOfWeek'.split()
featuresAsset = 'assetCodeId assetNameId'.split()
featuresPriceAbsolute = 'close open'.split()
featuresPriceRelative = [f for f in F.columns if f not in set(featuresTime+featuresAsset+featuresPriceAbsolute)]
featuresSelection = featuresPriceRelative
F_ = F[featuresSelection]

lgb_data_info = dict(
    feature_name = list(F_.columns),
    categorical_feature = list(F_.dtypes[F_.dtypes==np.int64].index),
    free_raw_data = False,
)
L.tr = lgb.Dataset(F_[tr], P.target[tr], weight=P.weight1[tr], **lgb_data_info)
L.cv = lgb.Dataset(F_[cv], P.target[cv], reference=L.tr, weight=P.weight1[cv], **lgb_data_info)
L.ho = lgb.Dataset(F_[ho], P.target[ho], weight=P.weight1[ho], **lgb_data_info)

# %%
L.tr.timeFactor = P.time[tr].factorize()[0]
L.cv.timeFactor = P.time[cv].factorize()[0]
L.tr.value = (P.upDown1*P.absVal1)[tr]
L.cv.value = (P.upDown1*P.absVal1)[cv]
L.tr.i = 100
L.cv.i = 100

def lgb_kaggle_metric(preds, valid_data):
    df_time = valid_data.timeFactor
    #labels = valid_data.get_label()
    values = valid_data.value
    #assert len(labels) == len(df_time)

    preds = preds*2-1
    #labels = labels*2-1
    x_t = preds * values
    
    # Here we take advantage of the fact that `labels` (used to calculate `x_t`)
    # is a pd.Series and call `group_by`
    x_t_sum = x_t.groupby(df_time).sum()
    score = x_t_sum.mean() / x_t_sum.std()

    valid_data.i += lgb_kaggle_metric.hack
    return 'kaggle', score+valid_data.i, True
lgb_kaggle_metric.hack = 0

# %%
lgb_params = dict(
    #task = 'train',
    objective = 'binary',
    
    num_iterations = 1500,
    early_stopping_round = 150,
    
    learning_rate = .05, #0.05,
    num_leaves = 1<<12, #1<<12,
    max_depth = 12, #12,
    min_data_in_leaf = 150, #150,
    min_sum_hessian_in_leaf = 50, #50,
    #bagging_fraction = 1,
    #bagging_freq = 0,
    #feature_fraction = 1,
    lambda_l1 = 0.01, #0.01,
    lambda_l2 = 0.01, #0.01,
    min_gain_to_split = 0.0,
    
    #min_data_per_group = 100,
    #max_cat_threshold = 32,
    #cat_l2 = 10.0,
    #cat_smooth = 10.0,
    #max_cat_to_onehot = 4,
    
    #max_bin = 255,
    
    metric = 'None', # This will ignore the loss objetive and use sigma_score instead,
    
    seed = 44, # Change for better luck! :)
    bagging_seed = 45,
    feature_fraction_seed = 46,
    #data_random_seed = 1,
)

evals_result = {}
lgb_model = lgb.train(lgb_params, L.tr, valid_sets=[L.tr,L.cv], valid_names=['tr','cv'],
              feval=lgb_kaggle_metric, evals_result=evals_result, verbose_eval=10)


df_result = pd.DataFrame(evals_result['cv'])
# Out:
# Training until validation scores don't improve for 150 rounds.
# [10]	tr's kaggle: 100.673	cv's kaggle: 100.599
# [20]	tr's kaggle: 100.705	cv's kaggle: 100.617
# [30]	tr's kaggle: 100.715	cv's kaggle: 100.613
# [40]	tr's kaggle: 100.734	cv's kaggle: 100.616
# [50]	tr's kaggle: 100.748	cv's kaggle: 100.617
# [60]	tr's kaggle: 100.755	cv's kaggle: 100.614
# [70]	tr's kaggle: 100.756	cv's kaggle: 100.615
# [80]	tr's kaggle: 100.764	cv's kaggle: 100.618
# [90]	tr's kaggle: 100.768	cv's kaggle: 100.618
# [100]	tr's kaggle: 100.776	cv's kaggle: 100.62
# [110]	tr's kaggle: 100.783	cv's kaggle: 100.618
# [120]	tr's kaggle: 100.789	cv's kaggle: 100.621
# [130]	tr's kaggle: 100.793	cv's kaggle: 100.623
# [140]	tr's kaggle: 100.804	cv's kaggle: 100.625
# [150]	tr's kaggle: 100.81	cv's kaggle: 100.625
# [160]	tr's kaggle: 100.818	cv's kaggle: 100.624
# [170]	tr's kaggle: 100.827	cv's kaggle: 100.623
# [180]	tr's kaggle: 100.829	cv's kaggle: 100.624
# [190]	tr's kaggle: 100.833	cv's kaggle: 100.623
# [200]	tr's kaggle: 100.844	cv's kaggle: 100.62
# [210]	tr's kaggle: 100.851	cv's kaggle: 100.618
# [220]	tr's kaggle: 100.855	cv's kaggle: 100.617
# [230]	tr's kaggle: 100.864	cv's kaggle: 100.616
# [240]	tr's kaggle: 100.869	cv's kaggle: 100.616
# [250]	tr's kaggle: 100.874	cv's kaggle: 100.615
# [260]	tr's kaggle: 100.879	cv's kaggle: 100.615
# [270]	tr's kaggle: 100.885	cv's kaggle: 100.614
# [280]	tr's kaggle: 100.888	cv's kaggle: 100.612
# [290]	tr's kaggle: 100.89	cv's kaggle: 100.611
# [300]	tr's kaggle: 100.899	cv's kaggle: 100.611
# Early stopping, best iteration is:
# [154]	tr's kaggle: 100.816	cv's kaggle: 100.626

# %%
for ds, metrics in evals_result.items():
    for m_name, m_list in metrics.items():
        if m_name=='kaggle':
            for i,m in enumerate(m_list):
                m_list[i] = m % (lgb_kaggle_metric.hack or 1e6)
        else:
            for i,m in enumerate(m_list):
                m_list[i] *= -1

# %%
canvas(12,6)
fig, (ax0, ax1) = plt.subplots(1,2)
#ax = lgb.plot_metric(evals_result, metric='binary_logloss', ax=ax0);
ax = lgb.plot_metric(evals_result, metric='kaggle', ax=ax1);
canvas(12,12)

# %%
P['model'] = lgb_model.predict(F_)*2-1

# %%
P['guess'] = P.model
P.guess = P.guess*(np.abs(P.guess)>=0.0)

# %%
# ideal impossible strategies
#dayguess = P.groupby('time').apply(lambda p: ((p.upDown*p.absVal).sum()>0)*2-1)
#P.guess = P.time.map(dayguess)

# %%
P['trade'] = P.guess*P.upDown1*P.absVal1

# %%
daily = P[ho].groupby('time').trade.sum()
print(daily.mean()/daily.std(ddof=0))
plt.hist(daily, bins=80);
# Out:
# 0.5986618612218697

# %%
{
    2: 0.6168541885774534
    5: 0.6224710382873514,
    10: 0.6056370425353168,
    50: 0.6174873801629851, # better CV though, and overfits TR less
    100: 0.6108589386807013,
}

# %%
{
    50: 0.5905464091533569,
    10: 0.5943043430879086,
    5: 0.594418925891397,
    2: 0.5926460860469429,
    0: 0.586289632381248,
    
}
# Out:
#   File "<ipython-input-171-291e6a0d00ad>", line 5
#     2: 0.5926460860469429
#     ^
# SyntaxError: invalid syntax

# %%
raise Stop()

# %%
canvas(12,60)
print('extrafault')
lgb.plot_importance(lgb_model);
canvas(12,12)
# Out:
# extrafault

# %%
canvas(12,24)
# this is newfault
lgb.plot_importance(lgb_model);
canvas(12,12)

# %% [markdown]
# # SCRATCH

# %%
a = O(i=0)
b = O(i=555)

# %%
for i in range(2500):
    o = a
    m = test[o.i][0]
    add_basic_features(M=m)
    m = m[~m.assetCode.isna()]
    assetCodeIndexedDf.join(m.set_index('assetCode'))
    #w = m.pivot('time','assetCode')
    if i%100==0:
        print(i)
# Out:
# 0
# 100
# 200
# 300
# 400
# 500
# 600
# 700
# 800
# 900
# 1000
# 1100
# 1200
# 1300
# 1400
# 1500
# 1600
# 1700
# 1800
# 1900
# 2000
# 2100
# 2200
# 2300
# 2400
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-59-1d1ff24ca10e> in <module>()
#       4     add_basic_features(M=m)
#       5     m = m[~m.assetCode.isna()]
# ----> 6     assetCodeIndexedDf.join(m.set_index('assetCode'))
#       7     #w = m.pivot('time','assetCode')
#       8     if i%100==0:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in join(self, other, on, how, lsuffix, rsuffix, sort)
#    6334         # For SparseDataFrame's benefit
#    6335         return self._join_compat(other, on=on, how=how, lsuffix=lsuffix,
# -> 6336                                  rsuffix=rsuffix, sort=sort)
#    6337
#    6338     def _join_compat(self, other, on=None, how='left', lsuffix='', rsuffix='',
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _join_compat(self, other, on, how, lsuffix, rsuffix, sort)
#    6349             return merge(self, other, left_on=on, how=how,
#    6350                          left_index=on is None, right_index=True,
# -> 6351                          suffixes=(lsuffix, rsuffix), sort=sort)
#    6352         else:
#    6353             if on is not None:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in get_result(self)
#     566                 self.left, self.right)
#     567
# --> 568         join_index, left_indexer, right_indexer = self._get_join_info()
#     569
#     570         ldata, rdata = self.left._data, self.right._data
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/reshape/merge.py in _get_join_info(self)
#     763             join_index, left_indexer, right_indexer = \
#     764                 left_ax.join(right_ax, how=self.how, return_indexers=True,
# --> 765                              sort=self.sort)
#     766         elif self.right_index and self.how == 'left':
#     767             join_index, left_indexer, right_indexer = \
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in join(self, other, how, level, return_indexers, sort)
#    3811                 rindexer = None
#    3812             else:
# -> 3813                 rindexer = other.get_indexer(join_index)
#    3814             return join_index, lindexer, rindexer
#    3815         else:
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/category.py in get_indexer(self, target, method, limit, tolerance)
#     576
#     577         if (isinstance(target, CategoricalIndex) and
# --> 578                 self.values.is_dtype_equal(target)):
#     579             if self.values.equals(target.values):
#     580                 # we have the same codes
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/arrays/categorical.py in is_dtype_equal(self, other)
#    2240
#    2241         try:
# -> 2242             return hash(self.dtype) == hash(other.dtype)
#    2243         except (AttributeError, TypeError):
#    2244             return False
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/dtypes.py in __hash__(self)
#     179                 return -2
#     180         # We *do* want to include the real self.ordered here
# --> 181         return int(self._hash_categories(self.categories, self.ordered))
#     182
#     183     def __eq__(self, other):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/dtypes/dtypes.py in _hash_categories(categories, ordered)
#     248                     hashed = hash((tuple(categories), ordered))
#     249                     return hashed
# --> 250             cat_array = hash_array(np.asarray(categories), categorize=False)
#     251         if ordered:
#     252             cat_array = np.vstack([
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/util/hashing.py in hash_array(vals, encoding, hash_key, categorize)
#     290
#     291         try:
# --> 292             vals = hashing.hash_object_array(vals, hash_key, encoding)
#     293         except TypeError:
#     294             # we have mixed types
#
# KeyboardInterrupt:

# %%
guy = assetCodeIndexedDf.join(m.set_index('assetCode'))

# %%
{4:5}(({5:7}))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-3f36fd672ede> in <module>()
# ----> 1 {4:5}.extend(({5:7}))
#
# AttributeError: 'dict' object has no attribute 'extend'

# %%
for i in range(len(test)):
    assert (test[0][0].assetCode==test[0][2].assetCode).all()

# %%
pd.DataFrame([np.asarray([5,6,7]),np.asarray([2,0,9])],columns=[0,1,2],index=['one','two']).T[...]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3077             try:
# -> 3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Ellipsis
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-4bde75f2306c> in <module>()
# ----> 1 pd.DataFrame([np.asarray([5,6,7]),np.asarray([2,0,9])],columns=[0,1,2],index=['one','two']).T[...]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2686             return self._getitem_multilevel(key)
#    2687         else:
# -> 2688             return self._getitem_column(key)
#    2689
#    2690     def _getitem_column(self, key):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _getitem_column(self, key)
#    2693         # get column
#    2694         if self.columns.is_unique:
# -> 2695             return self._get_item_cache(key)
#    2696
#    2697         # duplicate columns & possible reduce dimensionality
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in _get_item_cache(self, item)
#    2487         res = cache.get(item)
#    2488         if res is None:
# -> 2489             values = self._data.get(item)
#    2490             res = self._box_item_values(item, values)
#    2491             cache[item] = res
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/internals.py in get(self, item, fastpath)
#    4113
#    4114             if not isna(item):
# -> 4115                 loc = self.items.get_loc(item)
#    4116             else:
#    4117                 indexer = np.arange(len(self.items))[isna(self.items)]
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078                 return self._engine.get_loc(key)
#    3079             except KeyError:
# -> 3080                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    3081
#    3082         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: Ellipsis

# %%
guy = test[0][2].copy()
guy.index = test[0][2].assetCode.astype(assetCodeCategorical)
guy = guy[~guy.index.isna()]
guyguy = test[100][2].copy()
guyguy.index = test[100][2].assetCode.astype(assetCodeCategorical)
guyguy = guyguy[~guyguy.index.isna()]
print(lens(guy,guyguy))
pd.concat([guyguy,guy],axis=0).index.isna().any()
# Out:
# (1821, 1774)
# False

# %%
guy
# Out:
#           assetCode  confidenceValue
# assetCode
# A.N             A.N              0.0
# AA.N           AA.N              0.0
# AAL.O         AAL.O              0.0
# AAN.N         AAN.N              0.0
# AAP.N         AAP.N              0.0
# AAPL.O       AAPL.O              0.0
# ABB.N         ABB.N              0.0
# ABBV.N       ABBV.N              0.0
# ABC.N         ABC.N              0.0
# ABCO.O       ABCO.O              0.0
# ABEV.N       ABEV.N              0.0
# ABM.N         ABM.N              0.0
# ABMD.O       ABMD.O              0.0
# ABT.N         ABT.N              0.0
# ABX.N         ABX.N              0.0
# ABY.O         ABY.O              0.0
# ACAD.O       ACAD.O              0.0
# ACC.N         ACC.N              0.0
# ACCO.N       ACCO.N              0.0
# ACGL.O       ACGL.O              0.0
# ACHC.O       ACHC.O              0.0
# ACIA.O       ACIA.O              0.0
# ACIW.O       ACIW.O              0.0
# ACM.N         ACM.N              0.0
# ACN.N         ACN.N              0.0
# ACOR.O       ACOR.O              0.0
# ACXM.O       ACXM.O              0.0
# ADBE.O       ADBE.O              0.0
# ADI.O         ADI.O              0.0
# ADM.N         ADM.N              0.0
# ...             ...              ...
# XLNX.O       XLNX.O              0.0
# XLRN.O       XLRN.O              0.0
# XNCR.O       XNCR.O              0.0
# XOG.O         XOG.O              0.0
# XOM.N         XOM.N              0.0
# XON.N         XON.N              0.0
# XPO.N         XPO.N              0.0
# XRAY.O       XRAY.O              0.0
# XXIA.O       XXIA.O              0.0
# XYL.N         XYL.N              0.0
# YELP.N       YELP.N              0.0
# YHOO.O       YHOO.O              0.0
# YNDX.O       YNDX.O              0.0
# YPF.N         YPF.N              0.0
# YRD.N         YRD.N              0.0
# YUM.N         YUM.N              0.0
# YUMC.N       YUMC.N              0.0
# YY.O           YY.O              0.0
# Z.O             Z.O              0.0
# ZAYO.N       ZAYO.N              0.0
# ZBH.N         ZBH.N              0.0
# ZBRA.O       ZBRA.O              0.0
# ZEN.N         ZEN.N              0.0
# ZG.O           ZG.O              0.0
# ZION.O       ZION.O              0.0
# ZIOP.O       ZIOP.O              0.0
# ZLTQ.O       ZLTQ.O              0.0
# ZNGA.O       ZNGA.O              0.0
# ZTO.N         ZTO.N              0.0
# ZTS.N         ZTS.N              0.0
#
# [1821 rows x 2 columns]

# %%
test[100][2].reset_index()
# Out:
#       index assetCode  confidenceValue
# 0         0       A.N              0.0
# 1         1      AA.N              0.0
# 2         2     AAL.O              0.0
# 3         3     AAN.N              0.0
# 4         4    AAOI.O              0.0
# 5         5     AAP.N              0.0
# 6         6    AAPL.O              0.0
# 7         7     AAT.N              0.0
# 8         8    AAXN.O              0.0
# 9         9     ABB.N              0.0
# 10       10    ABBV.N              0.0
# 11       11     ABC.N              0.0
# 12       12    ABCO.O              0.0
# 13       13    ABEV.N              0.0
# 14       14     ABM.N              0.0
# 15       15    ABMD.O              0.0
# 16       16     ABT.N              0.0
# 17       17     ABX.N              0.0
# 18       18     ABY.O              0.0
# 19       19    ACAD.O              0.0
# 20       20     ACC.N              0.0
# 21       21    ACCO.N              0.0
# 22       22    ACGL.O              0.0
# 23       23    ACHC.O              0.0
# 24       24    ACIA.O              0.0
# 25       25    ACIW.O              0.0
# 26       26     ACM.N              0.0
# 27       27     ACN.N              0.0
# 28       28    ACXM.O              0.0
# 29       29    ADBE.O              0.0
# ...     ...       ...              ...
# 1800   1800      XL.N              0.0
# 1801   1801    XLNX.O              0.0
# 1802   1802    XLRN.O              0.0
# 1803   1803    XNCR.O              0.0
# 1804   1804     XOG.O              0.0
# 1805   1805     XOM.N              0.0
# 1806   1806     XON.N              0.0
# 1807   1807    XPER.O              0.0
# 1808   1808     XPO.N              0.0
# 1809   1809    XRAY.O              0.0
# 1810   1810     XYL.N              0.0
# 1811   1811    YELP.N              0.0
# 1812   1812    YHOO.O              0.0
# 1813   1813     YIN.O              0.0
# 1814   1814    YNDX.O              0.0
# 1815   1815     YPF.N              0.0
# 1816   1816     YUM.N              0.0
# 1817   1817    YUMC.N              0.0
# 1818   1818      YY.O              0.0
# 1819   1819       Z.O              0.0
# 1820   1820    ZAYO.N              0.0
# 1821   1821     ZBH.N              0.0
# 1822   1822    ZBRA.O              0.0
# 1823   1823     ZEN.N              0.0
# 1824   1824      ZG.O              0.0
# 1825   1825    ZION.O              0.0
# 1826   1826    ZIOP.O              0.0
# 1827   1827    ZNGA.O              0.0
# 1828   1828     ZTO.N              0.0
# 1829   1829     ZTS.N              0.0
#
# [1830 rows x 3 columns]

# %%
# Out:
# dict_keys([{.assetName}, {.volume}, {.close}, {.open}, {.returnsClosePrevRaw1}, {.returnsOpenPrevRaw1}, {.returnsClosePrevMktres1}, {.returnsOpenPrevMktres1}, {.returnsClosePrevRaw10}, {.returnsOpenPrevRaw10}, {.returnsClosePrevMktres10}, {.returnsOpenPrevMktres10}, {.returnsOpenNextMktres10}, {.universe}, {.cc}, {.oo}, {.cc0}, {.oo0}, {.cc_10}, {.oo_10}, {.cc0_10}, {.oo0_10}, {.pseudo_target}, {.assetName_}, {.volume_}, {.close_}, {.open_}, {.returnsClosePrevRaw1_}, {.returnsOpenPrevRaw1_}, {.returnsClosePrevMktres1_}, {.returnsOpenPrevMktres1_}, {.returnsClosePrevRaw10_}, {.returnsOpenPrevRaw10_}, {.returnsClosePrevMktres10_}, {.returnsOpenPrevMktres10_}, {.returnsOpenNextMktres10_}, {.universe_}, {.cc_}, {.oo_}, {.cc0_}, {.oo0_}, {.cc_10_}, {.oo_10_}, {.cc0_10_}, {.oo0_10_}, {.pseudo_target_}, {.df}, {.af}, {.it}, 'oo{01/}', 'oo{0123/}', 'oo{012345/}', 'oo{01234567/}', 'oo{0123456789/}', 'oo{23/}', 'oo{2345/}', 'oo{234567/}', 'oo{23456789/}', 'oo{45/}', 'oo{4567/}', 'oo{456789/}', 'oo{67/}', 'oo{6789/}', 'oo{89/}', 'oo0_10{0/3}', 'oo0_10{0/6}', 'oo0_10{0/9}', 'oo0_10{3/6}', 'oo0_10{3/9}', 'oo0_10{6/9}', '(it/af)', '(af/it[1])', '(it/it[1])', '(it,af,it[1],oo,cc){0/1}', '(it,af,it[1],oo,cc){0/2}', '(it,af,it[1],oo,cc){0/3}', '(it,af,it[1],oo,cc){0/4}', '(it,af,it[1],oo,cc){1/2}', '(it,af,it[1],oo,cc){1/3}', '(it,af,it[1],oo,cc){1/4}', '(it,af,it[1],oo,cc){2/3}', '(it,af,it[1],oo,cc){2/4}', '(it,af,it[1],oo,cc){3/4}', '(it,af,it[1],oo0,cc0){0/1}', '(it,af,it[1],oo0,cc0){0/2}', '(it,af,it[1],oo0,cc0){0/3}', '(it,af,it[1],oo0,cc0){0/4}', '(it,af,it[1],oo0,cc0){1/2}', '(it,af,it[1],oo0,cc0){1/3}', '(it,af,it[1],oo0,cc0){1/4}', '(it,af,it[1],oo0,cc0){2/3}', '(it,af,it[1],oo0,cc0){2/4}', '(it,af,it[1],oo0,cc0){3/4}'])

# %%
M.head()[[]]
# Out:
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3, 4]
